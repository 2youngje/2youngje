# %% [markdown]
# <a href="https://colab.research.google.com/github/2youngje/2youngje/blob/main/pandas_basic.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Pandas

# %% [markdown]
# ## Seris

# %%
import pandas as pd
prices = [1000,1010,1020]
seris1 = pd.Series(prices)
seris1
# Out:
# 0    1000
# 1    1010
# 2    1020
# dtype: int64

# %%
dates = pd.date_range('20230101', periods=3)
series2 = pd.Series(prices, index = dates)
series2
# Out:
# 2023-01-01    1000
# 2023-01-02    1010
# 2023-01-03    1020
# Freq: D, dtype: int64

# %%
pd.date_range('2022-01-01', '2023-01-01', freq = 'M')
# Out:
# DatetimeIndex(['2022-01-31', '2022-02-28', '2022-03-31', '2022-04-30',
#                '2022-05-31', '2022-06-30', '2022-07-31', '2022-08-31',
#                '2022-09-30', '2022-10-31', '2022-11-30', '2022-12-31'],
#               dtype='datetime64[ns]', freq='M')

# %%
pd.date_range('2022-01-01', '2023-01-01', freq = 'MS')
# Out:
# DatetimeIndex(['2022-01-01', '2022-02-01', '2022-03-01', '2022-04-01',
#                '2022-05-01', '2022-06-01', '2022-07-01', '2022-08-01',
#                '2022-09-01', '2022-10-01', '2022-11-01', '2022-12-01',
#                '2023-01-01'],
#               dtype='datetime64[ns]', freq='MS')

# %%
series2['2023-01-04'] = 1030

# %%
series2[1:3]
# Out:
# 2023-01-02    1010
# 2023-01-03    1020
# Freq: D, dtype: int64

# %%
series2[2]
# Out:
# 1020

# %%
series2['2023-01-03']
# Out:
# 1020

# %%
series2[2] = 1080

# %%
series2
# Out:
# 2023-01-01    1000
# 2023-01-02    1010
# 2023-01-03    1080
# 2023-01-04    1030
# Freq: D, dtype: int64

# %% [markdown]
# ## DataFrame

# %%
prices = {
    'SK텔레콤' : [44000, 44500, 45000],
    '삼성전자' : [70100, 70200, 70300],
    'LG전자'   : [85000, 85500, 86000]
}
df1 = pd.DataFrame(prices)
df1
# Out:
#    SK텔레콤   삼성전자   LG전자
# 0  44000  70100  85000
# 1  44500  70200  85500
# 2  45000  70300  86000

# %%
df2 = pd.DataFrame(prices, index = dates)
df2
# Out:
#             SK텔레콤   삼성전자   LG전자
# 2023-01-01  44000  70100  85000
# 2023-01-02  44500  70200  85500
# 2023-01-03  45000  70300  86000

# %% [markdown]
# ### 데이터 선택
# - loc : index, column으로 데이터를 가져온다.
# - iloc : 데이터 순서로 데이터를 가져온다.

# %%
df2.iloc[0]
# Out:
# SK텔레콤    44000
# 삼성전자     70100
# LG전자     85000
# Name: 2023-01-01 00:00:00, dtype: int64

# %%
df2.iloc[:,0]
# Out:
# 2023-01-01    44000
# 2023-01-02    44500
# 2023-01-03    45000
# Freq: D, Name: SK텔레콤, dtype: int64

# %%
df2.iloc[0,0]
# Out:
# 44000

# %%
df2.loc['2023-01-02']
# Out:
# SK텔레콤    44500
# 삼성전자     70200
# LG전자     85500
# Name: 2023-01-02 00:00:00, dtype: int64

# %%
df2.loc[:,'SK텔레콤']
# Out:
# 2023-01-01    44000
# 2023-01-02    44500
# 2023-01-03    45000
# Freq: D, Name: SK텔레콤, dtype: int64

# %%
df2['SK텔레콤']
# Out:
# 2023-01-01    44000
# 2023-01-02    44500
# 2023-01-03    45000
# Freq: D, Name: SK텔레콤, dtype: int64

# %%
df2.SK텔레콤
# Out:
# 2023-01-01    44000
# 2023-01-02    44500
# 2023-01-03    45000
# Freq: D, Name: SK텔레콤, dtype: int64

# %%
df2['POSCO'] = [450000, 455000, 460000]
df2
# Out:
#             SK텔레콤   삼성전자   LG전자   POSCO
# 2023-01-01  44000  70100  85000  450000
# 2023-01-02  44500  70200  85500  455000
# 2023-01-03  45000  70300  86000  460000

# %%
#실습
#Q1. 2023년 1월 2일 ~ 2023 1월 3일 까지의 '삼성전자', 'LG전자' 데이터를 가져와주세요.
df2.iloc[[1,2],[1,2]]
# Out:
#              삼성전자   LG전자
# 2023-01-02  70200  85500
# 2023-01-03  70300  86000

# %%
df2.loc['2023-01-02':,'삼성전자':'LG전자']
# Out:
#              삼성전자   LG전자
# 2023-01-02  70200  85500
# 2023-01-03  70300  86000

# %%
#Q2. 데이터 70200원 가져오기 (iloc, loc 각각 활용)
df2.iloc[1,1]
# Out:
# 70200

# %%
df2.삼성전자[1]
# Out:
# 70200

# %%
df1.loc[1,'삼성전자']
# Out:
# 70200

# %% [markdown]
# ### 데이터프레임 확장
# - concat : 그냥 가져다 붙이는 것
# - merge : 공통된 칼럼이나 인덱스가 있는 경우

# %%
s1 = pd.Series([500000,500500,501000],index = dates, name = 'LG화학')

# %%
concat_df2 = pd.concat([df2, s1], axis = 1)
concat_df2
# Out:
#             SK텔레콤   삼성전자   LG전자   POSCO    LG화학
# 2023-01-01  44000  70100  85000  450000  500000
# 2023-01-02  44500  70200  85500  455000  500500
# 2023-01-03  45000  70300  86000  460000  501000

# %%
concat_df2['LG화학_add_500'] = concat_df2['LG화학']+500
concat_df2
# Out:
#             SK텔레콤   삼성전자   LG전자   POSCO    LG화학  LG화학_add_500
# 2023-01-01  44000  70100  85000  450000  500000        500500
# 2023-01-02  44500  70200  85500  455000  500500        501000
# 2023-01-03  45000  70300  86000  460000  501000        501500

# %%
concat_df2.loc['2023-01-06',:] = [44000,70100,85000,455000,550000,505000]
concat_df2
# Out:
#               SK텔레콤     삼성전자     LG전자     POSCO      LG화학  LG화학_add_500
# 2023-01-01  44000.0  70100.0  85000.0  450000.0  500000.0      500500.0
# 2023-01-02  44500.0  70200.0  85500.0  455000.0  500500.0      501000.0
# 2023-01-03  45000.0  70300.0  86000.0  460000.0  501000.0      501500.0
# 2023-01-06  44000.0  70100.0  85000.0  455000.0  550000.0      505000.0

# %%
concat_df2.loc['2023-01-05',:] = concat_df2.loc['2023-01-06',:] - 100
concat_df2
# Out:
#               SK텔레콤     삼성전자     LG전자     POSCO      LG화학  LG화학_add_500
# 2023-01-01  44000.0  70100.0  85000.0  450000.0  500000.0      500500.0
# 2023-01-02  44500.0  70200.0  85500.0  455000.0  500500.0      501000.0
# 2023-01-03  45000.0  70300.0  86000.0  460000.0  501000.0      501500.0
# 2023-01-06  44000.0  70100.0  85000.0  455000.0  550000.0      505000.0
# 2023-01-05  43900.0  70000.0  84900.0  454900.0  549900.0      504900.0

# %%
concat_df2.sort_index()
# Out:
#               SK텔레콤     삼성전자     LG전자     POSCO      LG화학  LG화학_add_500
# 2023-01-01  44000.0  70100.0  85000.0  450000.0  500000.0      500500.0
# 2023-01-02  44500.0  70200.0  85500.0  455000.0  500500.0      501000.0
# 2023-01-03  45000.0  70300.0  86000.0  460000.0  501000.0      501500.0
# 2023-01-05  43900.0  70000.0  84900.0  454900.0  549900.0      504900.0
# 2023-01-06  44000.0  70100.0  85000.0  455000.0  550000.0      505000.0

# %% [markdown]
# ### 데이터 정렬

# %%
concat_df2.sort_values(by='삼성전자', ascending=False)
# Out:
#               SK텔레콤     삼성전자     LG전자     POSCO      LG화학  LG화학_add_500
# 2023-01-03  45000.0  70300.0  86000.0  460000.0  501000.0      501500.0
# 2023-01-02  44500.0  70200.0  85500.0  455000.0  500500.0      501000.0
# 2023-01-01  44000.0  70100.0  85000.0  450000.0  500000.0      500500.0
# 2023-01-06  44000.0  70100.0  85000.0  455000.0  550000.0      505000.0
# 2023-01-05  43900.0  70000.0  84900.0  454900.0  549900.0      504900.0

# %% [markdown]
# ## 데이터 삭제

# %%
concat_df2.drop('2023-01-03', inplace = True)

# %%
concat_df2
# Out:
#               SK텔레콤     삼성전자     LG전자     POSCO      LG화학  LG화학_add_500
# 2023-01-01  44000.0  70100.0  85000.0  450000.0  500000.0      500500.0
# 2023-01-02  44500.0  70200.0  85500.0  455000.0  500500.0      501000.0
# 2023-01-06  44000.0  70100.0  85000.0  455000.0  550000.0      505000.0
# 2023-01-05  43900.0  70000.0  84900.0  454900.0  549900.0      504900.0

# %%
concat_df2.drop('LG화학_add_500', axis=1)
# Out:
#               SK텔레콤     삼성전자     LG전자     POSCO      LG화학
# 2023-01-01  44000.0  70100.0  85000.0  450000.0  500000.0
# 2023-01-02  44500.0  70200.0  85500.0  455000.0  500500.0
# 2023-01-06  44000.0  70100.0  85000.0  455000.0  550000.0
# 2023-01-05  43900.0  70000.0  84900.0  454900.0  549900.0

# %%
concat_df2.drop(['LG화학','LG화학_add_500'], axis=1)
# Out:
#               SK텔레콤     삼성전자     LG전자     POSCO
# 2023-01-01  44000.0  70100.0  85000.0  450000.0
# 2023-01-02  44500.0  70200.0  85500.0  455000.0
# 2023-01-06  44000.0  70100.0  85000.0  455000.0
# 2023-01-05  43900.0  70000.0  84900.0  454900.0

# %% [markdown]
# ### 데이터프레임 다루기

# %%
concat_df2['sum'] = concat_df2.sum(axis=1)
concat_df2
# Out:
#               SK텔레콤     삼성전자     LG전자     POSCO      LG화학  LG화학_add_500  \
# 2023-01-01  44000.0  70100.0  85000.0  450000.0  500000.0      500500.0
# 2023-01-02  44500.0  70200.0  85500.0  455000.0  500500.0      501000.0
# 2023-01-06  44000.0  70100.0  85000.0  455000.0  550000.0      505000.0
# 2023-01-05  43900.0  70000.0  84900.0  454900.0  549900.0      504900.0
#
#                   sum
# 2023-01-01  4948800.0
# 2023-01-02  4970100.0
# 2023-01-06  5127300.0
# 2023-01-05  5125500.0

# %%
concat_df2.min(axis=0)
# Out:
# SK텔레콤             43900.0
# 삼성전자              70000.0
# LG전자              84900.0
# POSCO            450000.0
# LG화학             500000.0
# LG화학_add_500     500500.0
# sum             4948800.0
# dtype: float64

# %%
concat_df2.describe()
# Out:
#              SK텔레콤          삼성전자         LG전자         POSCO           LG화학  \
# count      4.00000      4.000000      4.00000       4.00000       4.000000
# mean   44100.00000  70100.000000  85100.00000  453725.00000  525100.000000
# std      270.80128     81.649658    270.80128    2483.78072   28695.063455
# min    43900.00000  70000.000000  84900.00000  450000.00000  500000.000000
# 25%    43975.00000  70075.000000  84975.00000  453675.00000  500375.000000
# 50%    44000.00000  70100.000000  85000.00000  454950.00000  525200.000000
# 75%    44125.00000  70125.000000  85125.00000  455000.00000  549925.000000
# max    44500.00000  70200.000000  85500.00000  455000.00000  550000.000000
#
#         LG화학_add_500           sum
# count       4.000000  4.000000e+00
# mean   502850.000000  5.042925e+06
# std      2433.789912  9.678286e+04
# min    500500.000000  4.948800e+06
# 25%    500875.000000  4.964775e+06
# 50%    502950.000000  5.047800e+06
# 75%    504925.000000  5.125950e+06
# max    505000.000000  5.127300e+06

# %%
concat_df2.sort_index(inplace=True)

# %% [markdown]
# ### 결측치 처리
#
# - 제거 : dropna
# - 대체 : fillna,interpolate

# %%
import numpy as np
concat_df2.loc['2023-01-05','LG전자':'LG화학'] = np.NaN
concat_df2
# Out:
#               SK텔레콤     삼성전자     LG전자     POSCO      LG화학  LG화학_add_500  \
# 2023-01-01  44000.0  70100.0  85000.0  450000.0  500000.0      500500.0
# 2023-01-02  44500.0  70200.0  85500.0  455000.0  500500.0      501000.0
# 2023-01-05  43900.0  70000.0      NaN       NaN       NaN      504900.0
# 2023-01-06  44000.0  70100.0  85000.0  455000.0  550000.0      505000.0
#
#                   sum
# 2023-01-01  4948800.0
# 2023-01-02  4970100.0
# 2023-01-05  5125500.0
# 2023-01-06  5127300.0

# %%
concat_df2.dropna()
# Out:
#               SK텔레콤     삼성전자     LG전자     POSCO      LG화학  LG화학_add_500  \
# 2023-01-01  44000.0  70100.0  85000.0  450000.0  500000.0      500500.0
# 2023-01-02  44500.0  70200.0  85500.0  455000.0  500500.0      501000.0
# 2023-01-06  44000.0  70100.0  85000.0  455000.0  550000.0      505000.0
#
#                   sum
# 2023-01-01  4948800.0
# 2023-01-02  4970100.0
# 2023-01-06  5127300.0

# %%
concat_df2.dropna(axis=1)
# Out:
#               SK텔레콤     삼성전자  LG화학_add_500        sum
# 2023-01-01  44000.0  70100.0      500500.0  4948800.0
# 2023-01-02  44500.0  70200.0      501000.0  4970100.0
# 2023-01-05  43900.0  70000.0      504900.0  5125500.0
# 2023-01-06  44000.0  70100.0      505000.0  5127300.0

# %%
concat_df2.interpolate()
# Out:
#               SK텔레콤     삼성전자     LG전자     POSCO      LG화학  LG화학_add_500  \
# 2023-01-01  44000.0  70100.0  85000.0  450000.0  500000.0      500500.0
# 2023-01-02  44500.0  70200.0  85500.0  455000.0  500500.0      501000.0
# 2023-01-05  43900.0  70000.0  85250.0  455000.0  525250.0      504900.0
# 2023-01-06  44000.0  70100.0  85000.0  455000.0  550000.0      505000.0
#
#                   sum
# 2023-01-01  4948800.0
# 2023-01-02  4970100.0
# 2023-01-05  5125500.0
# 2023-01-06  5127300.0

# %% [markdown]
# #### Q1. 2022-01-01 ~ 2023-12-01 월초 인덱스를 생성

# %%
dfex = pd.date_range('2022-01-01', '2022-12-01', freq = 'MS')
dfex
# Out:
# DatetimeIndex(['2022-01-01', '2022-02-01', '2022-03-01', '2022-04-01',
#                '2022-05-01', '2022-06-01', '2022-07-01', '2022-08-01',
#                '2022-09-01', '2022-10-01', '2022-11-01', '2022-12-01'],
#               dtype='datetime64[ns]', freq='MS')

# %% [markdown]
# #### Q2. Q1에서 생성한 인덱스를 가지고 데이터프레임 생성(값은 자율, 이때 칼럼이름은 value)

# %%
value = {
    'SK텔레콤' : [44000, 44500, 45000,45000,50000,45000,52000,38000,58000,40000,42000,48000]
}
dfxe = pd.DataFrame(value, index = dfex)
dfxe
# Out:
#             SK텔레콤
# 2022-01-01  44000
# 2022-02-01  44500
# 2022-03-01  45000
# 2022-04-01  45000
# 2022-05-01  50000
# 2022-06-01  45000
# 2022-07-01  52000
# 2022-08-01  38000
# 2022-09-01  58000
# 2022-10-01  40000
# 2022-11-01  42000
# 2022-12-01  48000

# %% [markdown]
# #### Q3. value 칼럼에서 100을 더한 value_add_100 칼럼을 생성해주세요.

# %%
dfxe_100 = dfxe['SK텔레콤']+100
dfxe_100
# Out:
# 2022-01-01    44100
# 2022-02-01    44600
# 2022-03-01    45100
# 2022-04-01    45100
# 2022-05-01    50100
# 2022-06-01    45100
# 2022-07-01    52100
# 2022-08-01    38100
# 2022-09-01    58100
# 2022-10-01    40100
# 2022-11-01    42100
# 2022-12-01    48100
# Freq: MS, Name: SK텔레콤, dtype: int64

# %% [markdown]
# #### Q4. value 칼럼과 value_add_100 칼럼을 평균한 mean 칼럼을 생성해주세요.

# %% [markdown]
# ### 중복제거

# %%
concat_df3 = concat_df2.copy()
concat_df4 = pd.concat([concat_df2, concat_df3])
concat_df4.drop_duplicates()
# Out:
#               SK텔레콤     삼성전자     LG전자     POSCO      LG화학  LG화학_add_500  \
# 2023-01-01  44000.0  70100.0  85000.0  450000.0  500000.0      500500.0
# 2023-01-02  44500.0  70200.0  85500.0  455000.0  500500.0      501000.0
# 2023-01-05  43900.0  70000.0      NaN       NaN       NaN      504900.0
# 2023-01-06  44000.0  70100.0  85000.0  455000.0  550000.0      505000.0
#
#                   sum
# 2023-01-01  4948800.0
# 2023-01-02  4970100.0
# 2023-01-05  5125500.0
# 2023-01-06  5127300.0

# %%
concat_df3.loc['2023-01-03',:] = concat_df2.loc['2023-01-06',:].copy()
concat_df2.sort_index(inplace = True)
concat_df3
# Out:
#               SK텔레콤     삼성전자     LG전자     POSCO      LG화학  LG화학_add_500  \
# 2023-01-01  44000.0  70100.0  85000.0  450000.0  500000.0      500500.0
# 2023-01-02  44500.0  70200.0  85500.0  455000.0  500500.0      501000.0
# 2023-01-05  43900.0  70000.0      NaN       NaN       NaN      504900.0
# 2023-01-06  44000.0  70100.0  85000.0  455000.0  550000.0      505000.0
# 2023-01-03  44000.0  70100.0  85000.0  455000.0  550000.0      505000.0
#
#                   sum
# 2023-01-01  4948800.0
# 2023-01-02  4970100.0
# 2023-01-05  5125500.0
# 2023-01-06  5127300.0
# 2023-01-03  5127300.0

# %%
idx = concat_df3['삼성전자'].drop_duplicates().index
concat_df3.loc[idx,:]
# Out:
#               SK텔레콤     삼성전자     LG전자     POSCO      LG화학  LG화학_add_500  \
# 2023-01-01  44000.0  70100.0  85000.0  450000.0  500000.0      500500.0
# 2023-01-02  44500.0  70200.0  85500.0  455000.0  500500.0      501000.0
# 2023-01-05  43900.0  70000.0      NaN       NaN       NaN      504900.0
#
#                   sum
# 2023-01-01  4948800.0
# 2023-01-02  4970100.0
# 2023-01-05  5125500.0
